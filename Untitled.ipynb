# %%
import os
import urllib.request as request

# pip install pyunpack
from pyunpack import Archive
# Nos va a pedir:
# pip install patool

# %%
# import urllib.request as request

# # Obtaining the data from the URL's
# url_front = 'https://www.indec.gob.ar/ftp/cuadros/menusuperior/eph/'
# file_name = 'EPH_usu_4_Trim_2021_txt.zip'

# print(url_front + file_name)

# request.urlopen(url_front + file_name).read()
# Out:
# https://www.indec.gob.ar/ftp/cuadros/menusuperior/eph/EPH_usu_4_Trim_2021_txt.zip
# b'<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n    <meta charset="utf-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <meta name="description" content="El Instituto Nacional de Estad\xc3\xadstica y Censos de la Rep\xc3\xbablica Argentina INDEC es el organismo que unifica y ejerce todas las actividades estad\xc3\xadsticas oficiales">\r\n    <meta name="keywords" content="Indices,Indicadores Econ\xc3\xb3micos,Producci\xc3\xb3n estad\xc3\xadstica,Poblaci\xc3\xb3n,Condiciones de Vida,Trabajo e Ingresos,Educaci\xc3\xb3n,Salud, Turismo y Cultura,\xc3\xadndices de Precios,Sector Agropecuario,Miner\xc3\xada y Energ\xc3\xada,Industria y Construcci\xc3\xb3n, Comercio y Servicios, Empresas,Cuentas Nacionales,Cuentas Internacionales,Comercio Exterior,Pobreza,Nuevas Tecnolog\xc3\xadas de la Informaci\xc3\xb3n y Comunicaci\xc3\xb3n">\r\n    <meta name="Author" content="INDEC, Instituto Nacional de Estadistica y Censos de la REPUBLICA ARGENTINA">\r\n    <meta name="google-site-verification" content="6DoD4D913F2dLFuodfWaUtxJVRX4ELNFKFMDrPxfiX8" />\r\n    <link rel="shortcut icon" type="image/png" href="/Images_WEBINDEC/fav1.png" />\r\n    <title>INDEC: Instituto Nacional de Estad\xc3\xadstica y Censos de la Rep\xc3\xbablica Argentina</title>\r\n    <link href="/Content/css?v=RGwnEiRYTLWLC4hif29vUDWmf7ZU9x2NgfSvsHEQK1s1" rel="stylesheet"/>\r\n\r\n    <script src="/bundles/modernizr?v=inCVuEFe6J4Q07A0AcRsbJic_UE5MwpRMNGcOtk94TE1"></script>\r\n\r\n    <link rel="stylesheet" type="text/css" href="/Content/custom.css">\r\n    \r\n    <link rel="stylesheet" type="text/css" href="/slick/slick.css">\r\n    <link rel="stylesheet" type="text/css" href="/slick/slick-theme.css">\r\n    <link rel="stylesheet" type="text/css" href="/Content/bootstrap-select.css">\r\n</head>\r\n<body>\r\n    <nav class="navbar navbar-expand-lg navbar-light">\r\n        <div class="container" style="position:relative;">\r\n\r\n            <a class="navbar-brand pointer-on" onclick="navpage(this);" data-view="Portada"><img class="logo-indec" src="/Images_WEBINDEC/Logo/Logo_Indec.png" /></a>\r\n            <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">\r\n                <span class="navbar-toggler-icon"></span>\r\n            </button>\r\n            <div class="float-eng card-texto3"><a class="" href="https://sitioanterior.indec.gob.ar" target="_blank" rel="noopener noreferrer"><span class="ahover pointer-on font-a">IR AL SITIO ANTERIOR</span></a><span class="font-a" style="font-size:16px;"> | </span><a class="ahover pointer-on font-a" onclick="navpage(this);" data-view="Institucional/Indec/Transparencia">TRANSPARENCIA</a><span class="font-a" style="font-size:16px;"> | </span><a class="ahover pointer-on font-a" onclick="navpage(this);" data-view="Institucional/Indec/QuienesSomosEng">ENGLISH</a></div>\r\n            <div class="collapse navbar-collapse" id="navbarSupportedContent2">\r\n                <ul class="navbar-nav ml-auto">\r\n                    <li class="nav-item active">\r\n                        <div class="contenedor-Redes-Nav">\r\n                            <a href="https://twitter.com/INDECargentina" class="mr-10px" target="_blank" rel="noopener noreferrer"><div class="redes-navT"></div></a>\r\n                            <a href="https://www.facebook.com/INDECArgentina" class="mr-10px" target="_blank" rel="noopener noreferrer"><div class="redes-navF"></div></a>\r\n                            <a href="https://www.youtube.com/c/INDECArgentina" class="mr-10px" target="_blank" rel="noopener noreferrer"><div class="redes-navY"></div></a>\r\n                            <a href="https://www.instagram.com/indecargentina/" class="mr-10px" target="_blank" rel="noopener noreferrer"><div class="redes-navI"> ...

# %%
# Obtaining the data from the URL's
url_front = 'https://www.indec.gob.ar/ftp/cuadros/menusuperior/eph/'

## Carpeta donde quedaran los datos
extract_dir = './microdatos/'

for y in range(2021, 2022):
    for Q in range(1, 5):
        file_name = 'EPH_usu_'+str(Q)+'_Trim_'+str(y)+'_txt.zip'
        full_file = os.path.join(os.getcwd(), extract_dir, file_name)

        # Descarga el rar solo si no existe.
        if not os.path.isfile(full_file):

            # Si no esta el directorio lo crea
            if not os.path.exists(extract_dir):
                os.makedirs(extract_dir)

            # Toma data del URL
            x = request.urlretrieve(url_front + file_name, full_file)

#         Archive(full_file).extractall(extract_dir)

# %%
x = request.urlretrieve(url_front + file_name, full_file)

# %%
x
# Out:
# ('/home/miglesia/repositories/microdatos-EPH-INDEC/./microdatos/EPH_usu_3_Trim_2021_txt.zip',
#  <http.client.HTTPMessage at 0x7fdc2831b190>)

# %%
request(url_front + file_name, full_file)
# Out:
# ('/home/miglesia/repositories/microdatos-EPH-INDEC/./microdatos/EPH_usu_3_Trim_2021_txt.zip',
#  <http.client.HTTPMessage at 0x7fdc28325340>)

# %%
url_front + file_name
# Out:
# 'https://www.indec.gob.ar/ftp/cuadros/menusuperior/eph/EPH_usu_3_Trim_2021_txt.zip'

# %%
request.urlopen(url_front + file_name).read()
# Out:
# b'<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n    <meta charset="utf-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <meta name="description" content="El Instituto Nacional de Estad\xc3\xadstica y Censos de la Rep\xc3\xbablica Argentina INDEC es el organismo que unifica y ejerce todas las actividades estad\xc3\xadsticas oficiales">\r\n    <meta name="keywords" content="Indices,Indicadores Econ\xc3\xb3micos,Producci\xc3\xb3n estad\xc3\xadstica,Poblaci\xc3\xb3n,Condiciones de Vida,Trabajo e Ingresos,Educaci\xc3\xb3n,Salud, Turismo y Cultura,\xc3\xadndices de Precios,Sector Agropecuario,Miner\xc3\xada y Energ\xc3\xada,Industria y Construcci\xc3\xb3n, Comercio y Servicios, Empresas,Cuentas Nacionales,Cuentas Internacionales,Comercio Exterior,Pobreza,Nuevas Tecnolog\xc3\xadas de la Informaci\xc3\xb3n y Comunicaci\xc3\xb3n">\r\n    <meta name="Author" content="INDEC, Instituto Nacional de Estadistica y Censos de la REPUBLICA ARGENTINA">\r\n    <meta name="google-site-verification" content="6DoD4D913F2dLFuodfWaUtxJVRX4ELNFKFMDrPxfiX8" />\r\n    <link rel="shortcut icon" type="image/png" href="/Images_WEBINDEC/fav1.png" />\r\n    <title>INDEC: Instituto Nacional de Estad\xc3\xadstica y Censos de la Rep\xc3\xbablica Argentina</title>\r\n    <link href="/Content/css?v=RGwnEiRYTLWLC4hif29vUDWmf7ZU9x2NgfSvsHEQK1s1" rel="stylesheet"/>\r\n\r\n    <script src="/bundles/modernizr?v=inCVuEFe6J4Q07A0AcRsbJic_UE5MwpRMNGcOtk94TE1"></script>\r\n\r\n    <link rel="stylesheet" type="text/css" href="/Content/custom.css">\r\n    \r\n    <link rel="stylesheet" type="text/css" href="/slick/slick.css">\r\n    <link rel="stylesheet" type="text/css" href="/slick/slick-theme.css">\r\n    <link rel="stylesheet" type="text/css" href="/Content/bootstrap-select.css">\r\n</head>\r\n<body>\r\n    <nav class="navbar navbar-expand-lg navbar-light">\r\n        <div class="container" style="position:relative;">\r\n\r\n            <a class="navbar-brand pointer-on" onclick="navpage(this);" data-view="Portada"><img class="logo-indec" src="/Images_WEBINDEC/Logo/Logo_Indec.png" /></a>\r\n            <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">\r\n                <span class="navbar-toggler-icon"></span>\r\n            </button>\r\n            <div class="float-eng card-texto3"><a class="" href="https://sitioanterior.indec.gob.ar" target="_blank" rel="noopener noreferrer"><span class="ahover pointer-on font-a">IR AL SITIO ANTERIOR</span></a><span class="font-a" style="font-size:16px;"> | </span><a class="ahover pointer-on font-a" onclick="navpage(this);" data-view="Institucional/Indec/Transparencia">TRANSPARENCIA</a><span class="font-a" style="font-size:16px;"> | </span><a class="ahover pointer-on font-a" onclick="navpage(this);" data-view="Institucional/Indec/QuienesSomosEng">ENGLISH</a></div>\r\n            <div class="collapse navbar-collapse" id="navbarSupportedContent2">\r\n                <ul class="navbar-nav ml-auto">\r\n                    <li class="nav-item active">\r\n                        <div class="contenedor-Redes-Nav">\r\n                            <a href="https://twitter.com/INDECargentina" class="mr-10px" target="_blank" rel="noopener noreferrer"><div class="redes-navT"></div></a>\r\n                            <a href="https://www.facebook.com/INDECArgentina" class="mr-10px" target="_blank" rel="noopener noreferrer"><div class="redes-navF"></div></a>\r\n                            <a href="https://www.youtube.com/c/INDECArgentina" class="mr-10px" target="_blank" rel="noopener noreferrer"><div class="redes-navY"></div></a>\r\n                            <a href="https://www.instagram.com/indecargentina/" class="mr-10px" target="_blank" rel="noopener noreferrer"><div class="redes-navI"> ...

# %%
# Pagina de data que no fue subida
'https://www.indec.gob.ar/ftp/cuadros/menusuperior/eph/EPH_usu_3_Trim_2021_txt.zip'
